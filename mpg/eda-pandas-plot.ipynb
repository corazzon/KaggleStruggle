# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("mpg")
df.shape
# Out:
# (398, 9)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
h = df.hist(figsize=(15, 6))

# %%
df["mpg"].hist()

# %%
df.plot.hist(figsize=(15, 3), alpha=0.5)

# %%
df.plot.hist(figsize=(15, 3), alpha=0.8, bins=100)

# %%
h = df.plot.hist(subplots=True, figsize=(10, 10), bins=50)

# %%
h = df.plot.hist(subplots=True, figsize=(10, 10), bins=50, sharex=False)

# %%
df["mpg"].plot.kde()

# %%
df.pivot(columns="origin", values="mpg").plot.hist(bins=50, alpha=0.5)

# %%
df.pivot(columns="origin", values="mpg").plot.kde()

# %%
g = df.pivot(columns="origin", values="mpg").plot.kde(subplots=True, figsize=(10, 6))
