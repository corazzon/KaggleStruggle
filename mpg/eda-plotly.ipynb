# %% [markdown]
# * [cufflinks · PyPI](https://pypi.org/project/cufflinks/)
# * [Pandas Plotting Backend | Python | Plotly](https://plotly.com/python/pandas-backend/)

# %%
# !pip install cufflinks

# %%
import pandas as pd
import seaborn as sns


import plotly.express as px
import cufflinks as cf
cf.go_offline(connected=True)

# pd.options.plotting.backend = "plotly"

sns.__version__
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# '0.11.0'

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !pip install seaborn

# %%
df = sns.load_dataset("mpg")
df.shape
# Out:
# (398, 9)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.describe(include="object")
# Out:
#        origin        name
# count     398         398
# unique      3         305
# top       usa  ford pinto
# freq      249           6

# %% [markdown]
# ## 수치형 변수의 시각화

# %%
df["mpg"].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %%
h = df.hist(figsize=(15, 10), bins=10)

# %%
df["acceleration"].iplot(kind="hist")
# Out:
# <div>
#
#
#             <div id="30a8b31a-24b6-4f4b-8b0a-5f98a586e736" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("30a8b31a-24b6-4f4b-8b0a-5f98a586e736")) {
#                     Plotly.newPlot(
#                         '30a8b31a-24b6-4f4b-8b0a-5f98a586e736',
# ...

# %%
df["acceleration"].plot(kind="density")

# %%
sns.kdeplot(df["acceleration"], shade=True)
sns.rugplot(df["acceleration"])

# %% [markdown]
# ### 두 개의 수치변수

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df.iplot(kind="scatter", x="horsepower", y="weight", mode='markers', title="horsepower & weight")
# Out:
# <div>
#
#
#             <div id="4c0f0384-6f6f-4f31-b9c4-c66beeb3af2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4c0f0384-6f6f-4f31-b9c4-c66beeb3af2b")) {
#                     Plotly.newPlot(
#                         '4c0f0384-6f6f-4f31-b9c4-c66beeb3af2b',
# ...

# %%
df.iplot(kind="reg", x="horsepower", y="weight", mode='markers', categories='origin')
# Out:
# <div>
#
#
#             <div id="3256c563-4b2a-423d-8ccc-cac80e7c2099" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3256c563-4b2a-423d-8ccc-cac80e7c2099")) {
#                     Plotly.newPlot(
#                         '3256c563-4b2a-423d-8ccc-cac80e7c2099',
# ...

# %%
df.iplot(kind="scatter", x="horsepower", y="weight", mode='markers', categories='origin', subplots=True)
# Out:
# <div>
#
#
#             <div id="b3699ad9-128f-48cc-8367-539e9f47991b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b3699ad9-128f-48cc-8367-539e9f47991b")) {
#                     Plotly.newPlot(
#                         'b3699ad9-128f-48cc-8367-539e9f47991b',
# ...

# %%
sns.regplot(data=df, x="horsepower", y="weight")

# %%
sns.residplot(data=df, x="horsepower", y="weight")

# %%
sns.lmplot(data=df, x="horsepower", y="weight", hue="origin", col="origin", truncate=False)

# %%
sns.jointplot(data=df, x="horsepower", y="weight",  kind='hex')

# %%
df_sample = df.sample(100, random_state=42)
df_sample
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 198  33.0          4          91.0        53.0    1795          17.4
# 396  28.0          4         120.0        79.0    2625          18.6
# 33   19.0          6         232.0       100.0    2634          13.0
# 208  13.0          8         318.0       150.0    3940          13.2
# 93   14.0          8         318.0       150.0    4237          14.5
# ..    ...        ...           ...         ...     ...           ...
# 378  38.0          4         105.0        63.0    2125          14.7
# 371  29.0          4         135.0        84.0    2525          16.0
# 280  21.5          6         231.0       115.0    3245          15.4
# 323  27.9          4         156.0       105.0    2800          14.4
# 75   14.0          8         318.0       150.0    4077          14.0
#
#      model_year origin                            name
# 198          76  japan                     honda civic
# ...

# %%
sns.pairplot(data=df_sample, hue="origin")

# %%
corr = df.corr()
corr
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
import numpy as np
mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(corr, annot=True, cmap="coolwarm", mask=mask, vmin=-1, vmax=1)

# %%
sns.lineplot(data=df, x="model_year", y="mpg", ci=None, estimator='sum')

# %%
sns.relplot(data=df, x="model_year", y="mpg", kind="line", ci=None, col="origin")

# %% [markdown]
# ### 범주형 데이터

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %%
df["origin"].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
df["origin"].value_counts().iplot(kind="bar", title="origin")
# Out:
# <div>
#
#
#             <div id="5487f8dd-d293-4517-8151-6fe91a49e6bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5487f8dd-d293-4517-8151-6fe91a49e6bb")) {
#                     Plotly.newPlot(
#                         '5487f8dd-d293-4517-8151-6fe91a49e6bb',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "origin", "orientation": "v", "text": "", "type": "bar", "x": ["usa", "japan", "europe"], "y": [249, 79, 70]}],
# ...

# %%
origin_cylinders = pd.crosstab(df["cylinders"], df["origin"])
origin_cylinders
# Out:
# origin     europe  japan  usa
# cylinders
# 3               0      4    0
# 4              63     69   72
# 5               3      0    0
# 6               4      6   74
# 8               0      0  103

# %%
origin_cylinders.iplot(kind="bar", title="cylinders")
# Out:
# <div>
#
#
#             <div id="a1afd73b-5fa5-4714-a7a8-63f841fe01a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a1afd73b-5fa5-4714-a7a8-63f841fe01a8")) {
#                     Plotly.newPlot(
#                         'a1afd73b-5fa5-4714-a7a8-63f841fe01a8',
# ...

# %%
origin_cylinders.T.iplot(kind="bar", title="origin")
# Out:
# <div>
#
#
#             <div id="5b3d2813-06b4-4ab0-94e3-353f47ef4972" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5b3d2813-06b4-4ab0-94e3-353f47ef4972")) {
#                     Plotly.newPlot(
#                         '5b3d2813-06b4-4ab0-94e3-353f47ef4972',
# ...

# %% [markdown]
# ### 두 개의 범주형 변수

# %%
df.groupby(["origin"])["horsepower"].mean()
# Out:
# origin
# europe     80.558824
# japan      79.835443
# usa       119.048980
# Name: horsepower, dtype: float64

# %%
sns.barplot(data=df, x="origin", y="horsepower", ci=None)

# %%
df.groupby(["origin"])["horsepower"].sum()
# Out:
# origin
# europe     5478.0
# japan      6307.0
# usa       29167.0
# Name: horsepower, dtype: float64

# %%
sns.barplot(data=df, x="origin", y="horsepower", estimator=np.sum)

# %%
sns.barplot(data=df, x="origin", y="horsepower", hue="cylinders")

# %%
sns.barplot(data=df, x="cylinders", y="horsepower", hue="origin")

# %%
df.groupby(["origin", "cylinders"])["horsepower"].sum().unstack()
# Out:
# cylinders      3       4      5       6        8
# origin
# europe       NaN  4777.0  247.0   454.0      NaN
# japan      397.0  5215.0    NaN   695.0      NaN
# usa          NaN  5586.0    NaN  7276.0  16305.0

# %%
sns.boxplot(data=df, x="origin", y="horsepower")

# %%
g = df.groupby("origin")["horsepower"].describe()
g
# Out:
#         count        mean        std   min    25%    50%    75%    max
# origin
# europe   68.0   80.558824  20.157871  46.0  69.75   76.5   90.0  133.0
# japan    79.0   79.835443  17.819199  52.0  67.00   75.0   95.0  132.0
# usa     245.0  119.048980  39.897790  52.0  88.00  105.0  150.0  230.0

# %%
Q3 = g.loc["europe", "75%"]
Q1 = g.loc["europe", "25%"]

IQR = Q3 - Q1
OUT_MAX = Q3 + (IQR * 1.5)
OUT_MIN = Q1 - (IQR * 1.5)
OUT_MAX, OUT_MIN
# Out:
# (120.375, 39.375)

# %%
sns.boxplot(x = g.loc["europe"])

# %%
sns.boxenplot(data=df, x="cylinders", y="horsepower", hue="origin")

# %%
sns.violinplot(data=df, x="cylinders", y="horsepower")

# %%
sns.scatterplot(data=df, x="cylinders", y="horsepower")

# %%
sns.stripplot(data=df, x="cylinders", y="horsepower")

# %%
sns.swarmplot(data=df, x="cylinders", y="horsepower", size=2)

# %% [markdown]
# ### subplots

# %%
sns.catplot(data=df, x="cylinders", y="horsepower", col="origin")

# %%
sns.catplot(data=df, x="cylinders", y="horsepower", col="origin", kind="box")

# %%
sns.catplot(data=df, x="cylinders", y="horsepower", hue="origin", col="origin", kind="violin")

# %%
sns.catplot(data=df, x="origin", hue="cylinders", col="cylinders", kind="count", col_wrap=3)

# %%
h = df.hist(figsize=(15, 10))

# %%
df_sub = df[["cylinders", "displacement"]]
df_sub.head()
# Out:
#    cylinders  displacement
# 0          8         307.0
# 1          8         350.0
# 2          8         318.0
# 3          8         304.0
# 4          8         302.0

# %%
df_sub.isnull().sum()
# Out:
# cylinders       0
# displacement    0
# dtype: int64

# %%
sns.relplot(data=df)

# %%
sns.relplot(data=df, kind="line")

# %%
sns.catplot(data=df, orient="h", kind="box")

# %%
sns.catplot(data=df, orient="h", kind="violin")
