# %% [markdown]
# ## [Pokemon with stats - Kaggle](https://www.kaggle.com/abcsds/pokemon)
#
# * 참고
#     *  [Grammer of graphics with plotnine (Optional) | Kaggle](https://www.kaggle.com/residentmario/grammer-of-graphics-with-plotnine-optional)
#     * [plotnine-examples/geom_point.ipynb at master · has2k1/plotnine-examples](https://github.com/has2k1/plotnine-examples/blob/master/plotnine_examples/examples/geom_point.ipynb)

# %%
# 출력데이터가 지저분하게 보이지 않도록 warnings을 불러왔다.
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from plotnine import *

# %%
pokemon = pd.read_csv('data/Pokemon.csv', index_col=0)
pokemon.shape
# Out:
# (800, 12)

# %%
pokemon.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 1 to 721
# Data columns (total 12 columns):
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 75.8+ KB

# %%
pokemon.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
pokemon.isnull().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pokemon.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# 공격과 방어에 대한 산점도
(ggplot(pokemon)
 + aes('Attack', 'Defense')
 + geom_point()
)
# Out:
# <ggplot: (-9223372036579657563)>

# %%
(ggplot(pokemon)
 + aes('Attack','Defense', color='Legendary')
 + geom_point()
 + ggtitle('Legendary 상태에 따른 공격과 방어 산점도')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# <ggplot: (-9223372036564608298)>

# %%
(ggplot(pokemon)
 + aes('HP', 'Attack', color='Legendary')
 + geom_point()
 + ggtitle('Legendary 상태에 따른 HP와 공격 산점도')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# <ggplot: (290183344)>

# %%
(ggplot(pokemon)
 + aes('Attack', 'Defense', color='HP')
 + geom_point()
 + ggtitle('HP에 따른 공격과 방어 산점도')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# <ggplot: (-9223372036564596420)>

# %%
p = ggplot(aes(x='Attack', y='Defense'), pokemon)

# %%
p + geom_point()
# Out:
# <ggplot: (290340879)>

# %%
p + geom_point(aes(color='factor(HP)'))
# Out:
# <ggplot: (290755178)>

# %%
p + geom_point(aes(color='Legendary'))
# Out:
# <ggplot: (290738226)>

# %%
p + geom_point(aes(color='Speed'))
# Out:
# <ggplot: (291025840)>

# %%
p + geom_point(aes(color='HP')) + scale_color_gradient(low='blue', high='red')
# Out:
# <ggplot: (-9223372036564034500)>

# %%
p + geom_point(aes(size='HP'))
# Out:
# <ggplot: (-9223372036563271964)>
