# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv("uci-secom.csv")
df.shape

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.describe()

# %%
df.describe().T.describe()

# %%
df.describe(include="object")

# %%
df.select_dtypes(include="number").agg(["skew", "kurt"]).T.describe()

# %%
df.select_dtypes(include="number").agg(["skew", "kurt"]).T.hist(figsize=(12, 3), bins=100);
