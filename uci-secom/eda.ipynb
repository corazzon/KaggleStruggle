# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv("uci-secom.csv")
df.shape

# %%
df.head()

# %%
df.tail()

# %%
df.info()
